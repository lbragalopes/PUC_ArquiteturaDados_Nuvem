# %%
# Comparando MSE e RMSE
mse_scores = [lr_mse, rf_mse, gbt_mse]
rmse_scores = [lr_rmse, rf_rmse, gbt_rmse]
models = ["Linear Regression", "Random Forest", "GBT"]

# Gráfico de barras para MSE
plt.bar(models, mse_scores)
plt.xlabel("Models")
plt.ylabel("MSE")
plt.title("Comparação MSE")
plt.show()

# Gráfico de barras para RMSE
plt.bar(models, rmse_scores)
plt.xlabel("Models")
plt.ylabel("RMSE")
plt.title("Comparação RMSE")
plt.show()

# %%
# Valores reais
real_values = lr_predictions.select("Nota_Consumidor").collect()
predicted_values = lr_predictions.select("prediction").collect()

# Gráfico de dispersão
plt.scatter(real_values, predicted_values)
plt.xlabel("Real Values")
plt.ylabel("Predicted Values")
plt.title("Linear Regression - Real Values vs Predicted Values")
plt.show()
